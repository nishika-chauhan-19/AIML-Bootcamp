# %% [markdown]
# <div style="
# background:#FCFEFF;
# padding:35px;
# border-radius:20px;
# text-align:center;
# border:8px solid #0F52BA;
# box-shadow:0 8px 20px rgba(15,82,186,0.20);
# ">
# <h1 style="
# margin:0;
# font-size:42px;
# font-family:'Segoe UI';
# color:#0B3D91;
# font-weight:700;
# ">
# Static Web Scraping
# </h1>
# <h2 style="
# margin-top:12px;
# font-size:30px;
# font-family:'Segoe UI';
# color:#00897B;
# font-weight:600;
# ">
# ⚽ Quotes to Scrape ⚽
# </h2>
# <p style="
# margin-top:18px;
# font-size:18px;
# text-align:center;
# line-height:1.8;
# font-family:'Segoe UI';
# color:#4A5568;
# ">
# Using <b>Python</b>, <b>Requests</b>, and <b>BeautifulSoup
# </p>
# </div>

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
#
# <h2 style="color:#0B3D91;margin-top:0;">
#
# 📖 Introduction
#
# </h2>
#
# <p style="
# font-size:17px;
# line-height:1.9;
# text-align:justify;
# color:#4A5568;
# ">
#
# Web scraping is a technique used to extract useful information from websites automatically. In this project, we will scrape quote data from a static website "Quotes to Scrape" using Python libraries like Requests, BeautifulSoup, and Pandas.
#
# The extracted data includes quotes, authors, and tags, which will be structured into a clean dataset for further analysis and storage
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
#
# <h2 style="color:#0B3D91;margin-top:0;">
#
# 🎯 Objectives
#
# </h2>
#
# <ul style="
# font-size:17px;
# line-height:2;
# color:#4A5568;
# text-align:justify;
# ">
#
# The main objectives of this project are:
#
# - To understand the basics of static website scraping.
# - To extract data from HTML pages.
# - To collect quote details such as:
#     - Quote Text
#     - Author Name
#     - Tags
# - To create a structured DataFrame using Pandas.
# - To export scraped data into a CSV file.
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
#
# <h2 style="color:#0B3D91;margin-top:0;">
#
# 🌍 Overview
#
# </h2>
#
# <p style="
# font-size:17px;
# line-height:1.9;
# text-align:justify;
# color:#4A5568;
# ">
#
# In this project, data will be extracted from:
#
# **Website:**
# https://quotes.toscrape.com/
#
# The website contains multiple quotes with their authors
# and related tags.
#
# The scraping workflow includes:
#
# 1. Sending a request to the website.
# 2. Extracting HTML content.
# 3. Parsing HTML using BeautifulSoup.
# 4. Finding required elements.
# 5. Extracting quote information.
# 6. Creating a DataFrame.
# 7. Saving data into CSV format.
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
#
# <h2 style="color:#0B3D91;margin-top:0;">
#
# 🛠 Tools & Technologies
#
# </h2>
#
# <ul style="
# font-size:17px;
# line-height:2;
# color:#4A5568;
# ">
#
# <li>Python</li>
#
# <li>Requests</li>
#
# <li>BeautifulSoup (bs4)</li>
#
# <li>Pandas</li>
#
# <li>Jupyter Notebook</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# ⚽ Importing the Required Libraries
# </h2>
# </div>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# ⚽ Extracting of Content
# </h2>
# </div>

# %%
url = "https://quotes.toscrape.com/"

response = requests.get(url)

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# ⚽ Checking the Status Code
# </h2>
# </div>

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# ⚽ Parsing the Content
# </h2>
# </div

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content , "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
soup = BeautifulSoup(response.content , "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
# ...

# %%
soup = BeautifulSoup(response.text, "html.parser")

print(soup.title.text)
# Out:
# Quotes to Scrape

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# ⚽ Fetching the data
# </h2>
# </div

# %%
quotes_data = []

quotes = soup.find_all("div", class_="quote")

for i, quote in enumerate(quotes, start=1):

    text = quote.find("span", class_="text").text
    
    author = quote.find("small", class_="author").text
    
    tags = quote.find_all("a", class_="tag")
    tag_list = [tag.text for tag in tags]

    quotes_data.append([
        i,
        text,
        author,
        ", ".join(tag_list)
    ])

quotes_data
# Out:
# [[1,
#   '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#   'Albert Einstein',
#   'change, deep-thoughts, thinking, world'],
#  [2,
#   '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#   'J.K. Rowling',
#   'abilities, choices'],
#  [3,
#   '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#   'Albert Einstein',
#   'inspirational, life, live, miracle, miracles'],
#  [4,
#   '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#   'Jane Austen',
#   'aliteracy, books, classic, humor'],
#  [5,
#   "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#   'Marilyn Monroe',
#   'be-yourself, inspirational'],
#  [6,
# ...

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# ⚽ Creating dataframe
# </h2>
# </div

# %%
df = pd.DataFrame(
    quotes_data,
    columns=[
        "S.No",
        "Quote",
        "Author",
        "Tags"
    ]
)

df
# Out:
#    S.No                                              Quote             Author  \
# 0     1  “The world as we have created it is a process ...    Albert Einstein
# 1     2  “It is our choices, Harry, that show what we t...       J.K. Rowling
# 2     3  “There are only two ways to live your life. On...    Albert Einstein
# 3     4  “The person, be it gentleman or lady, who has ...        Jane Austen
# 4     5  “Imperfection is beauty, madness is genius and...     Marilyn Monroe
# 5     6  “Try not to become a man of success. Rather be...    Albert Einstein
# 6     7  “It is better to be hated for what you are tha...         André Gide
# 7     8  “I have not failed. I've just found 10,000 way...   Thomas A. Edison
# 8     9  “A woman is like a tea bag; you never know how...  Eleanor Roosevelt
# 9    10  “A day without sunshine is like, you know, nig...       Steve Martin
#
#                                            Tags
# 0        change, deep-thoughts, thinking, world
# ...

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# ⚽ Export csv
# </h2>
# </div

# %%
df.to_csv(
    "quotes_data.csv",
    index=False
)

# %% [markdown]
# <div style="
# background:#FCFEFF;
# border-left:8px solid #0F52BA;
# padding:22px;
# border-radius:15px;
# margin-top:25px;
# box-shadow:0 5px 15px rgba(15,82,186,0.15);
# ">
# <h2 style="color:#0B3D91;margin-top:0;">
# Thankyou
# </h2>
# </div
