# %% [markdown]
# <div style="
# background: #FFF8F4;
# border-top: 6px solid #B22222;
# border-bottom: 6px solid #B22222;
# border-left: 4px solid #B22222;
# border-right: 4px solid #B22222;
# border-radius: 22px;
# padding: 45px 30px;
# width: 96%;
# margin: 30px auto;
# text-align: center;
# box-shadow: 0 10px 25px rgba(139,30,30,0.15);
# ">
#
# <h1 style="
# color:#8B1E1E;
# font-family: Georgia, serif;
# font-size:46px;
# font-weight:bold;
# letter-spacing:4px;
# margin-bottom:18px;
# ">
# ▶ WEB SCRAPING ◀
# </h1>
#
# <hr style="
# width:65%;
# border:2px solid #B22222;
# margin:18px auto 25px auto;
# ">
#
# <h2 style="
# color:#4A2C2A;
# font-family:'Trebuchet MS', sans-serif;
# font-size:25px;
# font-weight:bold;
# letter-spacing:2px;
# line-height:1.6;
# margin:0;
# ">
# YOUTUBE DYNAMIC WEB SCRAPING<br>
# USING PYTHON
# </h2>
#
# <hr style="
# width:65%;
# border:2px solid #B22222;
# margin:25px auto 18px auto;
# ">
#
# <p style="
# color:#7A3B3B;
# font-size:18px;
# font-family:Segoe UI, sans-serif;
# font-style:italic;
# margin-top:8px;
# text-align: center;
# ">
# Using Python, Selenium & BeautifulSoup
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:28px 35px;
# border-left:8px solid #B22222;
# border-radius:0px 20px 20px 0px;
# width:95%;
# margin:auto;
# ">
#
# <h1 style="
# color:#8B1E1E;
# font-family:Georgia,serif;
# font-size:26px;
# margin-bottom:20px;
# ">
# 📌 INTRODUCTION
# </h1>
#
# <p style="
# font-size:18px;
# line-height:1.9;
# color:#4A2C2A;
# text-align:justify;
# ">
#
# Web scraping is the process of automatically extracting data from websites using programming techniques. It helps collect large amounts of information efficiently without manually copying the data.
#
# </p>
#
# <p style="
# font-size:18px;
# line-height:1.9;
# color:#4A2C2A;
# text-align:justify;
# ">
#
# In this project, Selenium and BeautifulSoup are used to perform dynamic web scraping on YouTube. Since YouTube loads most of its content dynamically using JavaScript, Selenium renders the webpage while BeautifulSoup parses the HTML to extract useful video information.
#
# </p>
#
# <p style="
# font-size:18px;
# line-height:1.9;
# color:#4A2C2A;
# text-align:justify;
# ">
#
# The scraped data includes video titles, channel names, views, upload time, and video links, which can be further analyzed or stored in a structured CSV file.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:28px 35px;
# border-left:8px solid #B22222;
# border-radius:0px 20px 20px 0px;
# width:95%;
# margin:auto;
# ">
#
# <h1 style="
# color:#8B1E1E;
# font-family:Georgia,serif;
# font-size:26px;
# margin-bottom:20px;
# ">
# 🎯 OBJECTIVE
# </h1>
#
# <p style="
# font-size:18px;
# line-height:1.9;
# color:#4A2C2A;
# text-align:justify;
# ">
#
# The primary objective of this project is to perform dynamic web scraping on YouTube using Selenium and BeautifulSoup. The project aims to automate the extraction of video information such as titles, channel names, views, upload time, and video links. The collected data is organized into a structured format for further analysis and visualization.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:28px 35px;
# border-left:8px solid #B22222;
# border-radius:0px 20px 20px 0px;
# width:95%;
# margin:auto;
# ">
#
# <h1 style="
# color:#8B1E1E;
# font-family:Georgia,serif;
# font-size:26px;
# margin-bottom:20px;
# ">
# 🌐 ABOUT THE WEBSITE
# </h1>
#
# <p style="
# font-size:18px;
# line-height:1.9;
# color:#4A2C2A;
# text-align:justify;
# ">
#
# <b>Website:</b> https://www.youtube.com
#
# <br><br>
#
# YouTube is one of the world's largest online video-sharing platforms where users can watch, upload, and share videos across various categories such as education, technology, entertainment, gaming, music, and news. Most of its content is loaded dynamically, making Selenium essential for scraping data from the website.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:28px 35px;
# border-left:8px solid #B22222;
# border-radius:0px 20px 20px 0px;
# width:95%;
# margin:auto;
# ">
#
# <h1 style="
# color:#8B1E1E;
# font-family:Georgia,serif;
# font-size:26px;
# margin-bottom:20px;
# ">
# ❓ WHY IS YOUTUBE A DYNAMIC WEBSITE?
# </h1>
#
# <p style="
# font-size:18px;
# line-height:1.9;
# color:#4A2C2A;
# text-align:justify;
# ">
#
# YouTube is a dynamic website because most of its content is generated using JavaScript after the webpage loads. Search results, recommendations, comments, and other elements appear dynamically without refreshing the page. Selenium is therefore required to render the webpage completely before extracting the data.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:28px 35px;
# border-left:8px solid #B22222;
# border-radius:0px 20px 20px 0px;
# width:95%;
# margin:auto;
# ">
#
# <h1 style="
# color:#8B1E1E;
# font-family:Georgia,serif;
# font-size:26px;
# margin-bottom:20px;
# ">
# 🛠️ TOOLS & TECHNOLOGIES USED
# </h1>
#
# <ul style="
# font-size:18px;
# line-height:2;
# color:#4A2C2A;
# ">
#
# <li> Python</li>
# <li> Selenium</li>
# <li> BeautifulSoup</li>
# <li> Pandas</li>
#
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E; font-size:15px; font-family:Georgia, serif;">
# ★ Importing the Library
# </b>
#
# </div>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E; font-size:15px; font-family:Georgia, serif;">
# ★ Launching Chrome Browser
# </b>
#
# </div>

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.maximize_window()

driver.get("https://www.youtube.com/")
time.sleep(5)

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Waiting for the Webpage to Load
# </b>
#
# </div>

# %%
time.sleep(5)

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Extracting the HTML Source
# </b>
#
# </div>

# %%
html = driver.page_source

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Parsing the HTML
# </b>
#
# </div>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "html.parser")

# %%
print(soup.prettify())
# Out:
# <html color-version="v2_0" dark="" darker-dark-theme="" darker-dark-theme-deprecate="" lang="en" style="font-size: 62.5%;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing="">
#  <head>
#   <script data-loaded="true" id="js-1124342058" nonce="" src="https://static.doubleclick.net/instream/ad_status.js">
#   </script>
#   <script data-loaded="true" id="js-1065286052" nonce="" src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js">
#   </script>
#   <script data-original-src="/s/player/9b33d56a/player_es6.vflset/en_US/miniplayer.js" nonce="" src="/s/player/9b33d56a/player_es6.vflset/en_US/miniplayer.js">
#   </script>
#   <script data-original-src="/s/player/9b33d56a/player_es6.vflset/en_US/remote.js" nonce="" src="/s/player/9b33d56a/player_es6.vflset/en_US/remote.js">
#   </script>
#   <script data-original-src="/s/player/9b33d56a/player_es6.vflset/en_US/offline.js" nonce="" src="/s/player/9b33d56a/player_es6.vflset/en_US/offline.js">
# ...

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Searching for Videos
# </b>
#
# </div>

# %%
keyword = input("🔍 Enter Search Keyword: ")

search = driver.find_element(By.NAME, "search_query")
search.send_keys(keyword)
search.send_keys(Keys.ENTER)

time.sleep(5)

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
# Out:
# 🔍 Enter Search Keyword:  python

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Finding Video Containers
# </b>
#
# </div>

# %%
videos = soup.find_all("ytd-video-renderer")
len(videos)
# Out:
# 6

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Extracting Video Details
# </b>
#
# </div>

# %%
data = []
sno = 1

for video in videos:

    try:
        title = video.find("a", id="video-title").text.strip()
    except:
        title = "N/A"

    try:
        meta = video.find("div", id="metadata-line")
        spans = meta.find_all("span")

        views = spans[0].text.strip()
        upload = spans[1].text.strip()

    except:
        views = "N/A"
        upload = "N/A"

    data.append([sno, title, views, upload])

    sno += 1

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Creating DataFrame
# </b>
#
# </div>

# %%
df = pd.DataFrame(
    data,
    columns=["Title", "Channel", "Views", "Upload Time"]
)

df
# Out:
#    Title                                            Channel       Views  \
# 0      1  I coloured my hair again😨 (lost the bet) **vlo...  2.3M views
# 1      2  Fears to Fathom: Scratch Creek Horror with Ruc...  3.7M views
# 2      3  Guess Her Makeup Price... Ruchika's Challenge ...  6.3M views
# 3      4  Ruchika Surprised Me on Our First Anniversary ...  8.3M views
# 4      5                I tried Viral street foods of Delhi  5.1M views
# 5      6            My Husband did my Make-up *chaos101* 😭🤣    5M views
#
#     Upload Time
# 0   2 weeks ago
# 1   13 days ago
# 2  2 months ago
# 3   4 weeks ago
# 4  3 months ago
# 5   1 month ago

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:8px 15px;
# border-left:5px solid #B22222;
# width:95%;
# margin:20px auto 10px auto;
# border-radius:0 8px 8px 0;
# ">
#
# <b style="color:#8B1E1E;font-size:15px;font-family:Georgia,serif;">
# ★ Exporting Data to CSV
# </b>
#
# </div>

# %%
df.to_csv("youtube_videos.csv", index=False)

# %% [markdown]
# <div style="
# background:#FFF8F4;
# padding:30px;
# border-left:6px solid #B22222;
# border-radius:12px;
# text-align:center;
# width:95%;
# margin:auto;
# font-family:Georgia,serif;
# ">
#
# <h1 style="color:#8B1E1E;"> Thank You </h1>
#
# <p style="font-size:18px;color:#4A2C2A;line-height:1.8;">
#
# Thank you for exploring this YouTube Dynamic Web Scraping project.<br><br>
#
# This project demonstrates how Selenium and BeautifulSoup can be combined to extract data from dynamic websites and organize it into a structured dataset for further analysis.
#
# </p>
#
# <hr style="border:1px solid #D8B7A7;width:60%;">
#
# <h3 style="color:#8B1E1E;">
# Happy Learning!
# </h3>
#
# </div>
