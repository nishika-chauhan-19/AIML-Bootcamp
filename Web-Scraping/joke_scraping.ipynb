# %% [markdown]
# <div style="
# background:#fffdf5;
# border:3px solid #f4c430;
# border-radius:20px;
# padding:30px;
# text-align:center;
# box-shadow:0 5px 18px rgba(244,196,48,0.25);
# ">
#
# <h2 style="
# color:#b8860b;
# font-size:24px;
# font-weight:700;
# letter-spacing:2px;
# ">
# 🌐 API WEB SCRAPING
# </h2>
#
# <hr style="
# border:1px solid #f4c430;
# width:60%;
# ">
#
# <h1 style="
# color:#d4a017;
# font-size:38px;
# font-weight:800;
# ">
# 😂 Official Joke API 😂
# </h1>
#
# <h3 style="
# color:#555;
# font-size:18px;
# font-weight:500;
# ">
# ✨ REST API Data Extraction • JSON Processing • Pandas Analysis ✨
# </h3>
#
# </div>

# %% [markdown]
# <div style="
# background:#fffdf5;
# border-left:5px solid #f4c430;
# padding:20px;
# border-radius:12px;
# box-shadow:0 3px 12px rgba(244,196,48,0.15);
# ">
#
# <h2 style="color:#d4a017;">
# 📌 Introduction
# </h2>
#
# <p style="color:#444; font-size:16px; line-height:1.6;">
#
# API (Application Programming Interface) allows communication between different
# software applications. In this project, we will use the <b>Official Joke API</b>
# to fetch real-time joke data in JSON format.
#
# Using Python, we will send requests to the API endpoint, extract useful
# information from the JSON response, and convert the extracted data into a
# structured Pandas DataFrame for analysis.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#fffdf5;
# border-left:5px solid #f4c430;
# padding:20px;
# border-radius:12px;
# box-shadow:0 3px 12px rgba(244,196,48,0.15);
# ">
#
# <h2 style="color:#d4a017;">
# 🎯 Objective
# </h2>
#
# <ul style="color:#444; font-size:16px; line-height:1.8;">
#
# <li>Understand the working of REST APIs.</li>
#
# <li>Fetch real-time data from Official Joke API using Python.</li>
#
# <li>Process and extract information from JSON responses.</li>
#
# <li>Convert API data into a structured Pandas DataFrame.</li>
#
# <li>Export and analyze API-generated datasets.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <div style="
# background:#fffdf5;
# border-left:5px solid #f4c430;
# padding:20px;
# border-radius:12px;
# box-shadow:0 3px 12px rgba(244,196,48,0.15);
# ">
#
# <h2 style="color:#d4a017;">
# 📖 Project Overview
# </h2>
#
# <p style="color:#444; font-size:16px; line-height:1.6;">
#
# This project demonstrates API-based data extraction using Python.
# The Official Joke API provides joke information such as joke type,
# setup, and punchline in JSON format.
#
# The extracted data is processed using Python libraries like
# <b>Requests</b> and <b>Pandas</b>, allowing us to transform raw API
# responses into meaningful tabular data.
#
# </p>
#
# </div>

# %% [markdown]
# <div style="
# background:#fffdf5;
# border-left:5px solid #f4c430;
# padding:20px;
# border-radius:12px;
# box-shadow:0 3px 12px rgba(244,196,48,0.15);
# ">
#
# <h2 style="color:#d4a017;">
# 🛠️ Tools & Technologies
# </h2>
#
# <table style="
# width:100%;
# border-collapse:collapse;
# color:#444;
# font-size:16px;
# ">
#
# <tr style="background:#fff3c4;">
# <th style="padding:12px;border:1px solid #f4c430;">Category</th>
# <th style="padding:12px;border:1px solid #f4c430;">Technology</th>
# </tr>
#
# <tr>
# <td style="padding:12px;border:1px solid #f4c430;">Programming Language</td>
# <td style="padding:12px;border:1px solid #f4c430;"> Python</td>
# </tr>
#
# <tr>
# <td style="padding:12px;border:1px solid #f4c430;">API Handling</td>
# <td style="padding:12px;border:1px solid #f4c430;"> REST API, HTTP Requests</td>
# </tr>
#
# <tr>
# <td style="padding:12px;border:1px solid #f4c430;">Libraries</td>
# <td style="padding:12px;border:1px solid #f4c430;"> Requests, Pandas</td>
# </tr>
#
# <tr>
# <td style="padding:12px;border:1px solid #f4c430;">Data Format</td>
# <td style="padding:12px;border:1px solid #f4c430;"> JSON</td>
# </tr>
#
#
#
# </table>
#
# </div>

# %% [markdown]
# <div style="
# background:#fffdf5;
# border-left:5px solid #f4c430;
# padding:20px;
# border-radius:12px;
# box-shadow:0 3px 12px rgba(244,196,48,0.15);
# ">
#
# <h2 style="color:#d4a017;">
# 😂 Importing Required Libraries
# </h2>
#
# </div>

# %%
import requests
import pandas as pd

# %% [markdown]
# <div style="
# background:#fffdf5;
# border-left:5px solid #f4c430;
# padding:20px;
# border-radius:12px;
# box-shadow:0 3px 12px rgba(244,196,48,0.15);
# ">
#
# <h2 style="color:#d4a017;">
# 😂 API endpoint
# </h2>
#
# </div>

# %%
api_url = "https://official-joke-api.appspot.com/random_joke"

print("API Endpoint:")
print(api_url)
# Out:
# API Endpoint:
# https://official-joke-api.appspot.com/random_joke

# %% [markdown]
# <div style="
# background:#fffdf5;
# border-left:5px solid #f4c430;
# padding:20px;
# border-radius:12px;
# box-shadow:0 3px 12px rgba(244,196,48,0.15);
# ">
#
# <h2 style="color:#d4a017;">
# 😂 Sending API Request
# </h2>
#
# </div>

# %%
response = requests.get(api_url)
response
# Out:
# <Response [200]>

# %%
<div style="
background:#fffdf5;
border-left:5px solid #f4c430;
padding:20px;
border-radius:12px;
box-shadow:0 3px 12px rgba(244,196,48,0.15);
">

<h2 style="color:#d4a017;">
😂 Sending API Request 
</h2>

</div>
