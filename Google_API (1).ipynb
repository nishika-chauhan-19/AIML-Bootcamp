# %% [markdown]
# <div style="background:#020617;border-radius:20px;border:4px solid #22d3ee; padding:30px; text-align:center; border-radius:15px;">
#
# <h1 style="color:white; font-size:45px; letter-spacing:5px; text-shadow:0 0 15px #94a3b8;">
# 🤖 GOOGLE GEMINI API 🤖
# </h1>
#
# <h2 style="color:#22d3ee; font-size:24px; letter-spacing:2px; text-shadow:0 0 10px #22d3ee;">
# Built by google, Powered by AI
# </h2>
#
# </div>

# %% [markdown]
# <div style="
# background:#020617;
# border:2px solid #22d3ee;
# border-radius:18px;
# padding:30px;
# margin-top:25px;
# box-shadow:0 0 15px rgba(34,211,238,0.3);
# ">
#
# <h2 style="
# color:#22d3ee;
# font-size:15px;
# margin-bottom:20px;
# letter-spacing:2px;
# text-shadow:0 0 10px #ffffff;
# ">
# 📖 OVERVIEW
# </h2>
#
# <div style="
# color:white;
# font-size:18px;
# line-height:1.1;
# text-align:justify;
# ">
#
# Google Gemini API is Google's advanced Generative AI service that enables developers to build intelligent applications using powerful multimodal AI models. It can understand and generate text, analyze images, write and explain code, solve complex problems, and assist in a wide variety of real-world tasks.
# <br><br>
# The API provides fast, accurate, and context-aware responses, making it suitable for AI chatbots, virtual assistants, content generation, programming support, data analysis, document summarization, and automation. With simple API integration, developers can easily embed Gemini's capabilities into web, mobile, and desktop applications.
#
# </div>
# </div>

# %% [markdown]
# <div style="
# background:#020617;
# padding:15px;
# border-left:2px solid #22d3ee;
# border-right:2px solid #22d3ee;
# font-family:Arial, sans-serif;
# ">
#
# <h3 style="
# color:#67e8f9;
# font-size:18px;
# margin:0;
# text-shadow:0 0 8px #22d3ee;
# ">
# 🤖 Installing the required library
# </h3>
#
# </div>

# %%
# %pip install -q google-generativeai openai-whisper
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div style="
# background:#020617;
# padding:15px;
# border-left:2px solid #22d3ee;
# border-right:2px solid #22d3ee;
# font-family:Arial, sans-serif;
# ">
#
# <h3 style="
# color:#67e8f9;
# font-size:18px;
# margin:0;
# text-shadow:0 0 8px #22d3ee;
# ">
# 🤖 Importing the library
# </h3>
#
# </div>

# %%
import google.generativeai as genai
print(genai.__version__)
# Out:
# 0.8.6

# %% [markdown]
# <div style="
# background:#020617;
# padding:15px;
# border-left:2px solid #22d3ee;
# border-right:2px solid #22d3ee;
# font-family:Arial, sans-serif;
# ">
#
# <h3 style="
# color:#67e8f9;
# font-size:18px;
# margin:0;
# text-shadow:0 0 8px #22d3ee;
# ">
# 🤖 Configuring the API Key
# </h3>
#
# </div>

# %%
genai.configure(api_key="AQ.Ab8RN6Idw8fCuLgg4sdR--5Bp8gJQfnCHyZXAVfld-j1eOlj9w")
for model in genai.list_models():
    if "generateContent" in model.supported_generation_methods:
        print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# ...

# %% [markdown]
# <div style="
# background:#020617;
# padding:15px;
# border-left:2px solid #22d3ee;
# border-right:2px solid #22d3ee;
# font-family:Arial, sans-serif;
# ">
#
# <h3 style="
# color:#67e8f9;
# font-size:18px;
# margin:0;
# text-shadow:0 0 8px #22d3ee;
# ">
# 🤖 Generating Content with Gemini API
# </h3>
#
# </div>

# %%
import os 
import getpass

if not os.environ.get("GEMINI_API_KEY"):
         os.environ["GEMINI_API_KEY"]=getpass.getpass("paste your gemini api key")
print("API key loaded:", "GEMINI_API_KEY" in os.environ)
# Out:
# paste your gemini api key ········
# API key loaded: True

# %%
genai.configure(api_key=os.environ["GEMINI_API_KEY"])
model = genai.GenerativeModel("gemini-2.5-flash")
response=model.generate_content("Explain what an API is, in 2 simple sentences")
print(response.text)
# Out:
# An API (Application Programming Interface) is a set of rules that allows different software applications to communicate with each other. It defines how requests should be made and how information will be returned, enabling programs to share data and functionality.

# %% [markdown]
# <div style="
# background:#020617;
# padding:20px;
# border-left:2px solid #22d3ee;
# border-right:2px solid #22d3ee;
# text-align:center;
# font-family:Arial, sans-serif;
# ">
#
# <h2 style="
# color:#67e8f9;
# font-size:22px;
# letter-spacing:2px;
# text-shadow:0 0 10px #22d3ee;
# ">
# 🤖  THANK YOU 🤖
# </h2>
# </div>
